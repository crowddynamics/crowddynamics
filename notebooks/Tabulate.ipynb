# %%
import numpy as np

# %%
import pandas as pd

# %%
from tabulate import tabulate

# %%
import sympy

# %%
from sympy.abc import *

# %%
from sympy import *

# %%
from sympy import init_printing, latex

# %%
from astropy import units

# %%
init_printing(use_latex="mathjax")

# %%
pwd
# Out:
# '/home/jaan/Dropbox/Projects/Crowd-Dynamics/notebooks'

# %%
df = pd.read_csv("backup/agent.csv", index_col=["name"])

# %%
df["name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/jaan/anaconda/envs/py34/lib/python3.4/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-7ed04a634165> in <module>()
# ...
