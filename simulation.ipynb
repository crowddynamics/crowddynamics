# %%
from bokeh.plotting import figure, output_notebook, show

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b0d70cec-091d-4f70-96ad-aa8e0c14ea74">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Load source

# %%
import numba

# %%
from source.visualization import plots
from source.system import System
from simulations.bottleneck.config import constant, linear_wall, agent, goal

# %% [markdown]
# # Initial configuration

# %%
p = figure(height=600, width=600)
p.circle(agent.position[:, 0], 
         agent.position[:, 1], 
         radius=agent.radius[:, 0])

for w in linear_wall.linear_params:
    p.line(w[:, 0], w[:, 1])

show(p);
# Out:
#     <div class="plotdiv" id="2fd9274b-d882-45d2-a3a0-e3085470eecc"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2fd9274b-d882-45d2-a3a0-e3085470eecc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2fd9274b-d882-45d2-a3a0-e3085470eecc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8e846fdb-ca6c-49bb-83da-0f9faa3f33ab":{"roots":{"references":[{"attributes":{"plot":{"id":"b870467a-9818-4930-81fb-875f00c51676","subtype":"Figure","type":"Plot"}},"id":"2a7d444c-6442-4f1d-be33-21ef00d75a57","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[50.0,50.0],"y":[0.0,24.0]}},"id":"5351eee5-adec-43b8-a25d-339ac862afc6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3e9b8be5-483e-4aad-9e9e-913561a0996d","type":"ColumnDataSource"},"glyph":{"id":"f0bcabf8-5875-4e04-9767-26b193ef3da7","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"b9eb424d-d0d1-4588-8902-48df41c150ac","type":"Circle"},"selection_glyph":null},"id":"e9a29ff0-d44a-4123-a35a-972443297f65","type":"GlyphRenderer"},{"attributes":{},"id":"c08dfa36-416e-4d54-8d99-bcd0c5f1b15f","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,50.0],"y":[50.0,50.0]}},"id":"3fea44fd-6501-4928-b852-2becdb70cdbd","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"b870467a-9818-4930-81fb-875f00c51676","subtype":"Figure","type":"Plot"}},"id":"a9a7364d-31b2-4511-9057-e549f870f118","type":"PreviewSaveTool"},{"attributes":{},"id":"d7ba520a-3b60-40f6-8136-88725f120bd3","type":"ToolEvents"},{"attributes":{"plot":{"id":"b870467a-9818-4930-81fb-875f00c51676","subtype":"Figure","type":"Plot"}},"id":"4059b725-7227-42b0-b20d-d3aa8259b3d0","type":"WheelZoomTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d1b743ae-27f4-4c9a-b00b-ae7d02206594","type":"Line"},{"attributes":{"data_source":{"id":"5351eee5-adec-43b8-a25d-339ac862afc6","type":"ColumnDataSource"},"glyph":{"id":"2a02e7b7-19ae-45ed-9f2e-2b93ca2c86f7","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"884218a0-28e9-44b7-9ba6-96d748086986","type":"Line"},"selection_glyph":null},"id":"bc6b3215-4ec1-44fa-9583-485b5213a421","type":"GlyphRenderer"},{"attributes":{},"id":"4808287d-0a1b-43ac-a079-775d66742b1b","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"b870467a-9818-4930-81fb-875f00c51676","subtype":"Figure","type":"Plot"},"ticker":{"id":"4808287d-0a1b-43ac-a079-775d66742b1b","type":"BasicTicker"}},"id":"0e56d143-aba4-4b87-85c6-f1beda958494","type":"Grid"},{"attributes":{"data_source":{"id":"27a3f6d6-2a4d-4ff1-a51e-50470bdeac9b","type":"ColumnDataSource"},"glyph":{"id":"b0c623b5-c34c-4ebb-b4cd-5b22c67170b5","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"40453df1-f8bc-4ffc-92b9-d1e10ebdf829","type":"Line"},"selection_glyph":null},"id":"9b5f3230-a191-40e2-955f-cb43500424d1","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"b870467a-9818-4930-81fb-875f00c51676","subtype":"Figure","type":"Plot"}},"id":"032dd2b6-59fd-47c5-b356-07cd9f0aa781","type":"ResizeTool"},{"attributes":{"callback":null,"column_names":["x","y","radius"],"data":{"radius":[0.21031626298531214,0.2113023937550218,0.20740762557022133,0.20513170949961115,0.20058644568493394,0.20718658744039822,0.23473374251791798,0.21339831780883906,0.2291742097310475,0.2215553493722838,0.21856176936184718,0.2250129875262151,0.22231039154573284,0.20939753162439526,0.2183068927676055,0.22416430067388757,0.21533803412698732,0.2124747563119177,0.23377914451260012,0.22382557273890283,0.21738521105520092,0.23463479279100835,0.22117444885954246,0.22303814821395146,0.22992583565941754,0.22372029206123595,0.23365100587265752,0.21744746726357198,0.20967912288315024,0.210513186901244,0.2304026926496407,0.23083152596160353,0.22916241030359666,0.22599494839192177,0.2132475756853173,0.20168920567472534,0.21952461691181913,0.23342072193836455,0.19881632546517777,0.23097772165725303,0.23912622092183086,0.1951039087745381,0.21761651632975565,0.22748699150776047,0.2366134688756126,0.2220755263769769,0.21980868184756538,0.19731241635275643,0.2216844295975244,0.21504875933923046,0.2113376684924932,0.2204849225031115,0.228961563214884,0.22477934114874476,0.22900425098616545,0.21 ...

# %% [markdown]
# # Run simulation

# %%
simulation = System(constant, agent, linear_wall, goal)

# %%
for _ in simulation:
        pass
# Out:
# i: 000010 | 0000 | 25.5 ms | 230 ms
# i: 000020 | 0000 | 24.2 ms | 460 ms
# i: 000030 | 0000 | 23.8 ms | 690 ms
# i: 000040 | 0000 | 23.6 ms | 921 ms
# i: 000050 | 0000 | 23.5 ms | 1.15 s
# i: 000060 | 0000 | 23.4 ms | 1.38 s
# i: 000070 | 0000 | 22.3 ms | 1.54 s
# i: 000080 | 0000 | 21.4 ms | 1.69 s
# i: 000090 | 0000 | 21.4 ms | 1.91 s
# i: 000100 | 0000 | 21.6 ms | 2.14 s
# i: 000110 | 0000 | 21.7 ms | 2.37 s
# i: 000120 | 0001 | 21.8 ms | 2.6 s
# i: 000130 | 0001 | 21.9 ms | 2.83 s
# i: 000140 | 0001 | 22 ms | 3.06 s
# i: 000150 | 0001 | 22.1 ms | 3.29 s
# i: 000160 | 0001 | 22.1 ms | 3.52 s
# i: 000170 | 0001 | 21.8 ms | 3.69 s
# i: 000180 | 0001 | 21.7 ms | 3.88 s
# i: 000190 | 0001 | 21.5 ms | 4.07 s
# i: 000200 | 0001 | 21.6 ms | 4.3 s
# i: 000210 | 0001 | 21.7 ms | 4.54 s
# i: 000220 | 0001 | 21.7 ms | 4.75 s
# i: 000230 | 0003 | 21.4 ms | 4.91 s
# i: 000240 | 0003 | 21.2 ms | 5.07 s
# i: 000250 | 0003 | 21.1 ms | 5.26 s
# i: 000260 | 0004 | 21.2 ms | 5.49 s
# i: 000270 | 0004 | 21.3 ms | 5.73 s
# i: 000280 | 0004 | 21.4 ms | 5.97 s
# i: 000290 | 0004 | 21.5 ms | 6.21 s
# i: 000300 | 0006 | 21.6 ms | 6.45 s
# i: 000310 | 0007 | 21.6 ms | 6.69 s
# i: 000320 | 0007 | 21.7 ms | 6.93 s
# i: 000330 | 0007 | 21.8 ms | 7.17 s
# i: 000340 | 0008 | 21.9 ms | 7.41 s
# i: 000350 | 0008 | 21.9 ms | 7.66 s
# i: 000360 | 0008 | 22 ms | 7.9 s
# i: 000370 | 0008 | 22.1 ms | 8.15 s
# i: 000380 | 0011 | 22.1 ms | 8.38 s
# i: 000390 | 0012 | 22.1 ms | 8.58 s
# i: 000400 | 0012 | 21.9 ms | 8.75 s
# i: 000410 | 0014 | 21.8 ms | 8.92 s
# i: 000420 | 0015 | 21.9 ms | 9.16 s
# i: 000430 | 0016 | 21.8 ms | 9.33 s
# i: 000440 | 0017 | 21.7 ms | 9.52 s
# i: 000450 | 0018 | 21.7 ms | 9.74 s
# i: 000460 | 0018 | 21.6 ms | 9.92 s
# i: 000470 | 0018 | 21.5 ms | 10.1 s
# i: 000480 | 0020 | 21.6 ms | 10.3 s
# i: 000490 | 0021 | 21.7 ms | 10.6 s
# i: 000500 | 0021 | 21.8 ms | 10.9 s
# i: 000510 | 0023 | 21.8 ms | 11.1 s
# i: 000520 | 0025 | 21.8 ms | 11.3 s
# i: 000530 | 0026 | 21.9 ms | 11.6 s
# i: 000540 | 0027 | 21.9 ms | 11.8 s
# i: 000550 | 0027 | 21.9 ms | 12 s
# i: 000560 | 0029 | 22 ms | 12.3 s
# i: 000570 | 0030 | 21.9 ms | 12.5 s
# i: 000580 | 0032 | 22 ms | 12.7 s
# i: 000590 | 0032 | 22 ms | 13 s
# i: 000600 | 0033 | 22 ms | 13.2 s
# i: 000610 | 0035 | 21.9 ms | 13.4 s
# i: 000620 | 0036 | 22 ms | 13.6 s
# i: 000630 | 0036 | 22.1 ms | 13.9 s
# i: 000640 | 0037 | 22 ms | 14.1 s
# i: 000650 | 0038 | 22.1 ms | 14.3 s
# i: 000660 | 0040 | 22.2 ms | 14.6 s
# i: 000670 | 0042 | 22.3 ms | 14.9 s
# i: 000680 | 0042 | 22.3 ms | 15.2 s
# i: 000690 | 0042 | 22.3 ms | 15.4 s
# i: 000700 | 0044 | 22.4 ms | 15.6 s
# i: 000710 | 0047 | 22.4 ms | 15.8 s
# i: 000720 | 0047 | 22.3 ms | 16 s
# i: 000730 | 0048 | 22.3 ms | 16.3 s
# i: 000740 | 0049 | 22.4 ms | 16.6 s
# i: 000750 | 0051 | 22.5 ms | 16.8 s
# i: 000760 | 0052 | 22.5 ms | 17.1 s
# i: 000770 | 0053 | 22.5 ms | 17.3 s
# i: 000780 | 0054 | 22.5 ms | 17.5 s
# i: 000790 | 0056 | 22.5 ms | 17.7 s
# i: 000800 | 0057 | 22.4 ms | 17.9 s
# i: 000810 | 0059 | 22.4 ms | 18.1 s
# i: 000820 | 0061 | 22.5 ms | 18.4 s
# i: 000830 | 0062 | 22.6 ms | 18.7 s
# i: 000840 | 0063 | 22.7 ms | 19 s
# i: 000850 | 0064 | 22.7 ms | 19.2 s
# i: 000860 | 0065 | 22.7 ms | 19.5 s
# i: 000870 | 0066 | 22.8 ms | 19.8 s
# i: 000880 | 0067 | 22.8 ms | 20.1 s
# i: 000890 | 0068 | 22.9 ms | 20.4 s
# i: 000900 | 0070 | 22.9 ms | 20.6 s
# i: 000910 | 0070 | 22.9 ms | 20.8 s
# i: 000920 | 0071 | 23 ms | 21.1 s
# i: 000930 | 0074 | 23 ms | 21.4 s
# i: 000940 | 0075 | 23.1 ms | 21.6 s
# i: 000950 | 0078 | 23.1 ms | 21.9 s
# i: 000960 | 0079 | 23.1 ms | 22.1 s
# i: 000970 | 0080 | 23.1 ms | 22.4 s
# i: 000980 | 0081 | 23.1 ms | 22.6 s
# i: 000990 | 0083 | 23.1 ms | 22.8 s
# i: 001000 | 0083 | 23.1 ms | 23.1 s
# i: 001010 | 0086 | 23.1 ms | 23.3 s
# i: 001020 | 0087 | 23.1 ms | 23.5 s
# i: 001030 | 0088 | 23.1 ms | 23.8 s
# i: 001040 | 0089 | 23.2 ms | 24.1 s
# i: 001050 | 0091 | 23.2 ms | 24.3 s
# i: 001060 | 0093 | 23.2 ms | 24.6 s
# i: 001070 | 0095 | 23.2 ms | 24.8 s
# i: 001080 | 0095 | 23.2 ms | 25.1 s
# i: 001090 | 0098 | 23.2 ms | 25.3 s
# i: 001100 | 0099 | 23.2 ms | 25.5 s
# i: 001110 | 0099 | 23.1 ms | 25.7 s
# i: 001120 | 0100 | 23.2 ms | 25.9 s
# i: 001130 | 0102 | 23.2 ms | 26.2 s
# i: 001140 | 0103 | 23.1 ms | 26.3 s
# i: 001150 | 0104 | 23.1 ms | 26.5 s
# i: 001160 | 0107 | 23.1 ms | 26.8 s
# i: 001170 | 0107 | 23.1 ms | 27 s
# i: 001180 | 0109 | 23.1 ms | 27.2 s
# i: 001190 | 0109 | 23.1 ms | 27.5 s
# i: 001200 | 0112 | 23.2 ms | 27.8 s
# i: 001210 | 0113 | 23.2 ms | 28.1 s
# i: 001220 | 0115 | 23.2 ms | 28.3 s
# i: 001230 | 0116 | 23.2 ms | 28.5 s
# i: 001240 | 0117 | 23.2 ms | 28.8 s
# i: 001250 | 0118 | 23.2 ms | 29 s
# i: 001260 | 0118 | 23.3 ms | 29.3 s
# i: 001270 | 0118 | 23.3 ms | 29.5 s
# i: 001280 | 0120 | 23.2 ms | 29.7 s
# i: 001290 | 0120 | 23.2 ms | 29.9 s
# i: 001300 | 0121 | 23.2 ms | 30.2 s
# i: 001310 | 0122 | 23.3 ms | 30.5 s
# i: 001320 | 0124 | 23.3 ms | 30.7 s
# i: 001330 | 0127 | 23.3 ms | 31 s
# i: 001340 | 0127 | 23.3 ms | 31.2 s
# i: 001350 | 0127 | 23.3 ms | 31.4 s
# i: 001360 | 0128 | 23.3 ms | 31.6 s
# i: 001370 | 0130 | 23.3 ms | 31.8 s
# i: 001380 | 0132 | 23.3 ms | 32.1 s
# i: 001390 | 0133 | 23.3 ms | 32.4 s
# i: 001400 | 0134 | 23.3 ms | 32.6 s
# i: 001410 | 0135 | 23.3 ms | 32.9 s
# i: 001420 | 0136 | 23.3 ms | 33.1 s
# i: 001430 | 0138 | 23.4 ms | 33.4 s
# i: 001440 | 0139 | 23.3 ms | 33.6 s
# i: 001450 | 0140 | 23.3 ms | 33.8 s
# i: 001460 | 0141 | 23.3 ms | 34 s
# i: 001470 | 0141 | 23.3 ms | 34.2 s
# i: 001480 | 0143 | 23.3 ms | 34.4 s
# i: 001490 | 0145 | 23.2 ms | 34.6 s
# i: 001500 | 0145 | 23.2 ms | 34.8 s
# i: 001510 | 0146 | 23.2 ms | 35 s
# i: 001520 | 0149 | 23.2 ms | 35.2 s
# i: 001530 | 0150 | 23.1 ms | 35.4 s
# i: 001540 | 0150 | 23.1 ms | 35.6 s
# i: 001550 | 0150 | 23.1 ms | 35.8 s
# i: 001560 | 0153 | 23.1 ms | 36 s
# i: 001570 | 0153 | 23 ms | 36.2 s
# i: 001580 | 0155 | 23 ms | 36.4 s
# i: 001590 | 0156 | 23 ms | 36.5 s
# i: 001600 | 0156 | 23 ms | 36.8 s
# i: 001610 | 0158 | 23 ms | 37 s
# i: 001620 | 0158 | 23 ms | 37.2 s
# i: 001630 | 0160 | 22.9 ms | 37.4 s
# i: 001640 | 0161 | 22.9 ms | 37.6 s
# i: 001650 | 0162 | 22.9 ms | 37.8 s
# i: 001660 | 0163 | 23 ms | 38.1 s
# i: 001670 | 0164 | 22.9 ms | 38.3 s
# i: 001680 | 0165 | 22.9 ms | 38.4 s
# i: 001690 | 0165 | 22.9 ms | 38.6 s
# i: 001700 | 0166 | 22.8 ms | 38.8 s
# i: 001710 | 0166 | 22.8 ms | 38.9 s
# i: 001720 | 0166 | 22.7 ms | 39.1 s
# i: 001730 | 0167 | 22.7 ms | 39.2 s
# i: 001740 | 0169 | 22.7 ms | 39.5 s
# i: 001750 | 0169 | 22.7 ms | 39.7 s
# i: 001760 | 0171 | 22.7 ms | 39.9 s
# i: 001770 | 0172 | 22.7 ms | 40.1 s
# i: 001780 | 0173 | 22.7 ms | 40.4 s
# i: 001790 | 0175 | 22.7 ms | 40.6 s
# i: 001800 | 0176 | 22.6 ms | 40.7 s
# i: 001810 | 0177 | 22.6 ms | 40.9 s
# i: 001820 | 0177 | 22.6 ms | 41.1 s
# i: 001830 | 0179 | 22.6 ms | 41.3 s
# i: 001840 | 0179 | 22.6 ms | 41.5 s
# i: 001850 | 0181 | 22.6 ms | 41.7 s
# i: 001860 | 0182 | 22.6 ms | 42 s
# i: 001870 | 0183 | 22.6 ms | 42.2 s
# i: 001880 | 0183 | 22.5 ms | 42.4 s
# i: 001890 | 0185 | 22.5 ms | 42.5 s
# i: 001900 | 0186 | 22.5 ms | 42.7 s
# i: 001910 | 0186 | 22.5 ms | 42.9 s
# i: 001920 | 0187 | 22.4 ms | 43 s
# i: 001930 | 0188 | 22.4 ms | 43.2 s
# i: 001940 | 0189 | 22.4 ms | 43.5 s
# i: 001950 | 0191 | 22.4 ms | 43.6 s
# i: 001960 | 0191 | 22.4 ms | 43.8 s
# i: 001970 | 0191 | 22.3 ms | 44 s
# i: 001980 | 0193 | 22.3 ms | 44.1 s
# i: 001990 | 0193 | 22.3 ms | 44.3 s
# i: 002000 | 0194 | 22.3 ms | 44.5 s
# i: 002010 | 0195 | 22.3 ms | 44.8 s
# i: 002020 | 0196 | 22.3 ms | 45 s
# i: 002030 | 0196 | 22.3 ms | 45.2 s
# i: 002040 | 0197 | 22.3 ms | 45.4 s
# i: 002050 | 0198 | 22.3 ms | 45.6 s
# i: 002060 | 0198 | 22.2 ms | 45.8 s
# i: 002070 | 0198 | 22.2 ms | 46 s
# i: 002080 | 0199 | 22.2 ms | 46.1 s
# i: 002090 | 0199 | 22.2 ms | 46.3 s
# i: 002100 | 0199 | 22.2 ms | 46.5 s
# i: 002100 | 0200 | 22.2 ms | 46.5 s

# %%
t = simulation.result.agents_in_goal_times

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(t)
plt.show()
